# %% [markdown]
# <a href="https://colab.research.google.com/github/CamiloPZ/trabajos-finales/blob/master/Regresion_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><font face="Times" size="6px" color="#300000">Universidad Nacional de Ingeniería</font></center>
# <center><font face="Times" size="4px" color="#300000">Facultad de Ingeniería Económica, Estadística y Ciencias Sociales</font></center>
# <center><font face="Times" size="3px" color="#300000">Escuela Profesional de Ingeniería Estadística</font></center>
# <center><font face="Times" size="5px" color="#300000">Curso: Análisis de Regresión</font></center>
# <center><font face="Times" size="4px" color="#300000">Profesora: Pinedo Sánchez Amélida</font></center>
# <center><font face="Times" size="4px" color="#300000">Alumno: Poma Zamudio Camilo</font></center>
# <center><font face="Times" size="5px" color="#300000">Tema: Aplicación de los conocimientos adquiridos durante todo el curso</font></center>
# <center><font face="Times" size="4px" color="#300000">Ciclo Virtual: 2020 - I</font></center>
# <center><font face="Times" size="3px" color="#300000">Septiembre 2020</font></center>
#
# <!-- <center> <h2>Curso: Análisis de Regresión</h2> </center>
# <center> <h3>Profesora: Pinedo Sánchez Amélida</h3> </center>
# <center> <h3>Alumno: Poma Zamudio Camilo</h3> </center>
# <center> <h3>Tema: Aplicación de los conocimientos adquiridos durante todo el curso</h3> </center>
# <center> <h4>Ciclo Virtual: 2020 - I</h4> </center> -->

# %% [markdown]
# #Abstract:
#
# This work shows the applications of the most relevant topics seen in the Regression Analysis course in the virtual period 2020 - I. It starts from the descriptive analysis of the data, the formulation of the model, validation of the assumptions and estimates. Topics such as Multiple Linear Regression, ANOVA, Residual Analysis, Principal Component Analysis, among others, are mainly covered.
#
# **Keywords:** Multiple Linear Regression, ANOVA, Residual Analysis, Principal Component Analysis

# %% [markdown]
# #Resumen:
#
# En el presente trabajo se muestra las aplicaciones de los temas más relevantes vistos en el curso Análisis de Regresión en el periodo virtual 2020 - I. Se parte del análisis descriptivo de los datos, la formulación del modelo, validación de los supuestos y estimaciones. Se tocan principalmente temas como Regresión Lineal Múltiple, ANOVA, Análisis de Residuos, Análisis de Componentes Principales, entre otros.
#
# **Palabras Clave:** Regresión Lineal Múltiple, ANOVA, Análisis de Residuos, Análisis de Componentes Principales

# %% [markdown]
# # Introducción
#
# El análisis de Regresión es una de las herramientas estadísticas importantes que incluye técnicas de modelado y análisis de diversas variables. El análisis se centra en el estudio de la relación de una variable independiente y varias variables dependientes, de esta manera, el análisis de regresión ayuda a entender cómo el valor de la variable dependiente varía al cambiar el valor de las variables independientes.El análisis de regresión es ampliamente utilizado para la predicción y previsión, donde su uso tiene superposición sustancial en el campo de aprendizaje automático. Se utiliza también para comprender cuáles de las variables independientes están relacionadas con la variable dependiente, y explorar las formas de estas relaciones.
#
# Muchas técnicas han sido desarrolladas para llevar a cabo el análisis de regresión. Métodos familiares tales como la regresión lineal y la regresión por cuadrados mínimos ordinarios son paramétricos, en que la función de regresión se define en términos de un número finito de parámetros desconocidos que se estiman a partir de los datos.

# %% [markdown]
# # Objetivo
#
# Aplicar técnicas de análisis de regresión un conjunto de datos definido.

# %% [markdown]
# #Metodología
#
# Para un mejor entendimiento del análisis de regresión, en cada técnica utilizada se presentará brevemente el concepto teórico y su aplicación mediante el uso del lenguaje python.

# %% [markdown]
# # Recopilación de Datos
#
# Para este estudio, se consideró el conjunto de datos ... y se recomienda continuar la lectura de este informe en el siguiente link a fin de tener una mejor presentación de las gráficas.

# %% [markdown]
# # Análisis Exploratorio del Conjunto de Datos

# %%
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

def format_coefs(coefs):
    equation_list = [f"{coef}x^{i}" for i, coef in enumerate(coefs)]
    equation = "$" +  " + ".join(equation_list) + "$"

    replace_map = {"x^0": "", "x^1": "x", '+ -': '- '}
    for old, new in replace_map.items():
        equation = equation.replace(old, new)

    return equation

df = px.data.tips()
X = df.total_bill.values.reshape(-1, 1)
x_range = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)

fig = px.scatter(df, x='total_bill', y='tip', opacity=0.65)
for degree in [1, 2, 3, 4]:
    poly = PolynomialFeatures(degree)
    poly.fit(X)
    X_poly = poly.transform(X)
    x_range_poly = poly.transform(x_range)

    model = LinearRegression(fit_intercept=False)
    model.fit(X_poly, df.tip)
    y_poly = model.predict(x_range_poly)

    equation = format_coefs(model.coef_.round(2))
    fig.add_traces(go.Scatter(x=x_range.squeeze(), y=y_poly, name=equation))
fig.update_layout(autosize=False,width=600,
    height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5d30d82c-4adb-40e5-a898-6d971f955f4d" class="plotly-graph-div" style="height:400px; width:600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5d30d82c-4adb-40e5-a898-6d971f955f4d")) {
#                     Plotly.newPlot(
#                         '5d30d82c-4adb-40e5-a898-6d971f955f4d',
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=[1, 2, 3, 4], y=[0, 2, 3, 5],
                         fill='tozeroy',line_shape='spline')) 
fig.add_trace(go.Scatter(x=[1, 2, 3, 4], y=[3, 5, 1, 7], 
                         fill='tonexty',line_shape='spline')) 

fig.update_layout(autosize=False,width=600,
    height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2a927a5b-03cf-4cc2-a969-f594312182c7" class="plotly-graph-div" style="height:400px; width:600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2a927a5b-03cf-4cc2-a969-f594312182c7")) {
#                     Plotly.newPlot(
#                         '2a927a5b-03cf-4cc2-a969-f594312182c7',
# ...
